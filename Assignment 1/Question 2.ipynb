# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# Load the brain image (ensure the correct path)
image = cv.imread('a1images\\brain_proton_density_slice.png', cv.IMREAD_GRAYSCALE)

# Define the intensity transformation function to attenuate gray matter
def intensity_transformation(value):
    if 180 <= value <= 255:  # Gray matter intensities
        return int(1.5* value)  # Attenuate gray matter (reduce intensity by half)
    else:
        return value  # Leave other regions unchanged

# Apply the transformation to the image
transformed_image = np.zeros_like(image)
for i in range(image.shape[0]):
    for j in range(image.shape[1]):
        transformed_image[i, j] = intensity_transformation(image[i, j])

# Display the transformed image
plt.subplot(121), plt.imshow(image, cmap='gray'), plt.title('Original Image')
plt.subplot(122), plt.imshow(transformed_image, cmap='gray'), plt.title('Transformed Image (Gray Matter Accentuated)')
plt.show()

# Plot the transformation function
x = np.arange(0, 256)
y = [intensity_transformation(i) for i in x]
plt.plot(x, y)
plt.title('Gray Matter Intensity Transformation')
plt.xlabel('Input Intensity')
plt.ylabel('Output Intensity')
plt.show()
# Out:
# C:\Users\mihir\AppData\Local\Temp\ipykernel_29148\2018860083.py:19: DeprecationWarning: NumPy will stop allowing conversion of out-of-bound Python integers to integer arrays.  The conversion of 277 to uint8 will fail in the future.
# For the old behavior, usually:
#     np.array(value).astype(dtype)
# will give the desired result (the cast overflows).
#   transformed_image[i, j] = intensity_transformation(image[i, j])
# C:\Users\mihir\AppData\Local\Temp\ipykernel_29148\2018860083.py:19: DeprecationWarning: NumPy will stop allowing conversion of out-of-bound Python integers to integer arrays.  The conversion of 301 to uint8 will fail in the future.
# For the old behavior, usually:
#     np.array(value).astype(dtype)
# will give the desired result (the cast overflows).
#   transformed_image[i, j] = intensity_transformation(image[i, j])
# ...

# %% [markdown]
# // I'm not sure whether the grey matter is correctly attentuated here

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# Load the brain image (ensure the correct path)
image = cv.imread('a1images\\brain_proton_density_slice.png', cv.IMREAD_GRAYSCALE)

# Define the intensity transformation function to accentuate gray matter
def intensity_transformation(value):
    if 180 <= value <= 255:  # Gray matter intensities
        return min(255, int(2 * value))  # Enhance gray matter (boost intensities)
    else:
        return value  # Leave other regions unchanged

# Apply the transformation to the image
transformed_image = np.zeros_like(image)
for i in range(image.shape[0]):
    for j in range(image.shape[1]):
        transformed_image[i, j] = intensity_transformation(image[i, j])

# Display the transformed image
plt.subplot(121), plt.imshow(image, cmap='gray'), plt.title('Original Image')
plt.subplot(122), plt.imshow(transformed_image, cmap='gray'), plt.title('Transformed Image (Gray Matter Accentuated)')
plt.show()

# Plot the transformation function
x = np.arange(0, 256)
y = [intensity_transformation(i) for i in x]
plt.plot(x, y)
plt.title('Gray Matter Intensity Transformation')
plt.xlabel('Input Intensity')
plt.ylabel('Output Intensity')
plt.show()
